# %% [markdown]
# # Self-Study Colab Activity 1.1: Creating Hist, Scatter, Line, and Bar Plots

# %% [markdown]
# ### In this exercise, generate some basic charts using Pandas.

# %%
# import data from pandas
import pandas as pd
import os

#Make directory called plots
os.makedirs("plots", exist_ok=True)

#create the DataFrame utilizing Pandas 
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 

#generate all info for this dataset
data.info()

#Remove the last line of NAN
data = data.iloc[:-1 , :]

#Ignore any warnings
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# ###  Part One: In this exercise, generate a basic histogram.

# %%
#Please generate a basic histogram and save the histogram as a png file
# Hint: use pandas histogram function.
data.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot(kind='hist', figsize=(10, 6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Save the plot as a PNG file
#plt = data.plot
#plt.savefig('plots/data_histogram.png')
#Another option: hist = data.plot.hist()
histpng = data.savefig('plots/hist.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6152\498151709.py in ?()
#       1 # Save the plot as a PNG file
#       2 #plt = data.plot
#       3 #plt.savefig('plots/data_histogram.png')
#       4 #Another option: hist = data.plot.hist()
# ----> 5 histpng = data.savefig('plots/hist.png')
#
# c:\Users\Administrator\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'savefig'

# %% [markdown]
# ###  Part Two: In this exercise, generate a basic scatter plot.

# %%
#Please generate a basic scatter plot utilizing Age as the x axis and Salary as the y axis
# Hint: use pandas scatter function to generate the chart.

scat = data.plot.scatter(x='Age', y='Salary', figsize=(10, 6))
#Another option:
#scat = data.plot.scatter(x='Age',y='Salary')
#scatpng = scat.figure.savefig('plots/scat.png')

# Show the plot
print(scat)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ###  Part Three: In this exercise, generate a basic lineplot.

# %%
# Please generate a basic line plot by name as the x axis and salary as the y axis 
#for the "Golden State Warriors" using the nba data set. 
#Note a new dataframe called teamdata has been created for you that will be used during the rest of this 


teamdata = data.filter(items=['Team', 'Name', 'Salary'])
teamdata = teamdata.loc[data.Team == 'Golden State Warriors', 'Name':'Salary']
teamdata.set_index('Name')


lines = teamdata.plot(kind='line', y='Salary', figsize=(10, 6), legend=False)
plt.title('Salaries of Golden State Warriors Players')
plt.xlabel('Player Name')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.tight_layout()


#Another option:
#lines = teamdata.plot.line()

#lines.set_xticklabels(teamdata.Name, rotation=90) 
#linepng = lines.figure.savefig('plots/linepng.png')
# Show the plot
plt.show()

# ANSWER CHECK
print(lines)
# Out:
# Axes(0.0664028,0.111214;0.918597x0.829897)

# %% [markdown]
# ###  Part Four: In this exercise, generate a basic bar chart.

# %%
# Please generate a basic bar plot by name as the x axis and salary as the y axis of the teamdata dataframe.
 

bar = teamdata['Salary'].plot(kind='bar', figsize=(10, 6))
print(bar)

#Another option:
#barpng = bar.figure.savefig('plots/barpng.png')
# Out:
# Axes(0.125,0.11;0.775x0.77)
