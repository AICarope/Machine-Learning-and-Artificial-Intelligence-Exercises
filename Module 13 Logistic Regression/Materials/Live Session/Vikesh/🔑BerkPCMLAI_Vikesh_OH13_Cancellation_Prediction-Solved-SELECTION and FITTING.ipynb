# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Berkeley-PCMLAI:-Module-13:-Logistic-Regression" data-toc-modified-id="Berkeley-PCMLAI:-Module-13:-Logistic-Regression-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Berkeley PCMLAI: Module 13: Logistic Regression</a></span></li><li><span><a href="#OH-Agenda-📝" data-toc-modified-id="OH-Agenda-📝-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>OH Agenda 📝</a></span></li><li><span><a href="#Case-Study-📓:-Predict-Cancellation" data-toc-modified-id="Case-Study-📓:-Predict-Cancellation-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Case Study 📓: Predict Cancellation</a></span><ul class="toc-item"><li><span><a href="#-Import-modules-and-data-" data-toc-modified-id="-Import-modules-and-data--3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><font color="darkred"> Import modules and data </font></a></span></li><li><span><a href="#-Data-Inspection🔍📊" data-toc-modified-id="-Data-Inspection🔍📊-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><font color="darkred"> Data Inspection</font>🔍📊</a></span><ul class="toc-item"><li><span><a href="#-Numerical-inspection-and-summaries-" data-toc-modified-id="-Numerical-inspection-and-summaries--3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span><font color="darkred"> Numerical inspection and summaries </font></a></span></li><li><span><a href="#Creating-the-date-column" data-toc-modified-id="Creating-the-date-column-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Creating the date column</a></span></li></ul></li><li><span><a href="#-EDA-" data-toc-modified-id="-EDA--3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span><font color="darkred"> EDA </font></a></span><ul class="toc-item"><li><span><a href="#Numerical-enteries" data-toc-modified-id="Numerical-enteries-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Numerical enteries</a></span></li><li><span><a href="#Categorical-Values" data-toc-modified-id="Categorical-Values-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Categorical Values</a></span></li><li><span><a href="#Investigations" data-toc-modified-id="Investigations-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Investigations</a></span></li><li><span><a href="#Univariate-Analysis" data-toc-modified-id="Univariate-Analysis-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Univariate Analysis</a></span></li><li><span><a href="#Bivariate-Analysis" data-toc-modified-id="Bivariate-Analysis-3.3.5"><span class="toc-item-num">3.3.5&nbsp;&nbsp;</span>Bivariate Analysis</a></span></li></ul></li><li><span><a href="#-Data-Prep-for-Modeling-" data-toc-modified-id="-Data-Prep-for-Modeling--3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span><font color="darkred"> Data Prep for Modeling </font></a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Train-Test Split</a></span></li><li><span><a href="#Pre-processing" data-toc-modified-id="Pre-processing-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Pre-processing</a></span></li></ul></li><li><span><a href="#-Model-building--💥⚡" data-toc-modified-id="-Model-building--💥⚡-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span><font color="darkred"> Model building </font> 💥⚡</a></span></li><li><span><a href="#Model-Evaluation" data-toc-modified-id="Model-Evaluation-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Model Evaluation</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Explanation" data-toc-modified-id="Explanation-3.6.0.1"><span class="toc-item-num">3.6.0.1&nbsp;&nbsp;</span>Explanation</a></span></li></ul></li><li><span><a href="#Logistic-Regression-Model-Coefficients" data-toc-modified-id="Logistic-Regression-Model-Coefficients-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Logistic Regression Model Coefficients</a></span></li><li><span><a href="#ROC---AUC-Curve" data-toc-modified-id="ROC---AUC-Curve-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>ROC - AUC Curve</a></span></li></ul></li></ul></li><li><span><a href="#Reference-material-📚" data-toc-modified-id="Reference-material-📚-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Reference material 📚</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Berkeley PCMLAI: Module 13: Logistic Regression
#
#  👨‍🏫 **Vikesh K**
#  #️⃣**Office Hour # 13**
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# # OH Agenda 📝
#
# We will cover:
#
# * Cancellation Prediction
#     * EDA with respect to model building
#     * Data Prep
#     * Model Building
#     * Business Insights
#
#
#
#  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ❗❗ **Please refer to the OH recording to follow the steps down below. Please build further on the code below:** ❗❗
#
# Try to improve the prediction of the Logistic Regression model :
# * Expand the EDA to generate more business insights
# * Use the model with scaled dataset
# * Feature Selection
# * Do hyper parameter tuning using Gridsearch CV

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Case Study 📓: Predict Cancellation
#
# [Case Study Link](https://docs.google.com/document/d/1DrkN30mmBapBX146OvhscGHtAnjqkWkO7scGCNnLqvc/edit#heading=h.wpciijalbsdh)
#
#
# </div>

# %% [markdown]
# ##  <font color= darkred> Import modules and data </font>

# %%
# data manipulation
import pandas as pd
import numpy as np

# data viz
import matplotlib.pyplot as plt
import seaborn as sns
# plt.style.use("fivethirtyeight") # styling the charts

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Load Data**

# %%
url = 'https://raw.githubusercontent.com/vkoul/data/main/misc/hotel_bookings.csv'

df = pd.read_csv(url)

# %% [markdown]
# ##  <font color= darkred> Data Inspection</font>🔍📊

# %% [markdown]
# ### <font color= darkred> Numerical inspection and summaries </font>

# %% [markdown]
# **Data Inspect**

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             3               0                     0                  3
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0       Meal Plan 1                           0        Room_Type 1        224
# 1      Not Selected                           0        Room_Type 1          5
# 2       Meal Plan 1                           0        Room_Type 1          1
# 3       Meal Plan 1                           0        Room_Type 1        211
# 4      Not Selected                           0        Room_Type 1        277
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56926 entries, 0 to 56925
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          56926 non-null  int64
#  1   no_of_children                        56926 non-null  int64
#  2   no_of_weekend_nights                  56926 non-null  int64
#  3   no_of_week_nights                     56926 non-null  int64
#  4   type_of_meal_plan                     56926 non-null  object
#  5   required_car_parking_space            56926 non-null  int64
#  6   room_type_reserved                    56926 non-null  object
#  7   lead_time                             56926 non-null  int64
#  8   arrival_year                          56926 non-null  int64
#  9   arrival_month                         56926 non-null  int64
#  10  arrival_date                          56926 non-null  int64
# ...

# %% [markdown]
# ### Creating the date column

# %%
df = pd.read_csv(url, parse_dates = {"complete_date": ["arrival_year", "arrival_month", "arrival_date"]})

# %%
df.shape
# Out:
# (56926, 16)

# %%
df.head()
# Out:
#   complete_date  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0     2017 10 2             2               0                     1
# 1     2018 11 6             2               0                     2
# 2     2018 2 28             1               0                     2
# 3     2018 5 20             2               0                     0
# 4     2019 7 13             3               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  3      Not Selected                           0
#
#   room_type_reserved  lead_time market_segment_type  repeated_guest  \
# 0        Room_Type 1        224             Offline               0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56926 entries, 0 to 56925
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   complete_date                         56926 non-null  object
#  1   no_of_adults                          56926 non-null  int64
#  2   no_of_children                        56926 non-null  int64
#  3   no_of_weekend_nights                  56926 non-null  int64
#  4   no_of_week_nights                     56926 non-null  int64
#  5   type_of_meal_plan                     56926 non-null  object
#  6   required_car_parking_space            56926 non-null  int64
#  7   room_type_reserved                    56926 non-null  object
#  8   lead_time                             56926 non-null  int64
#  9   market_segment_type                   56926 non-null  object
#  10  repeated_guest                        56926 non-null  int64
# ...

# %%
# pd.to_datetime(df['complete_date'])

# %%
df = df.query('complete_date != "2018 2 29"')

# %%
df['complete_date'] = pd.to_datetime(df['complete_date']).copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56889 entries, 0 to 56925
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   complete_date                         56889 non-null  datetime64[ns]
#  1   no_of_adults                          56889 non-null  int64
#  2   no_of_children                        56889 non-null  int64
#  3   no_of_weekend_nights                  56889 non-null  int64
#  4   no_of_week_nights                     56889 non-null  int64
#  5   type_of_meal_plan                     56889 non-null  object
#  6   required_car_parking_space            56889 non-null  int64
#  7   room_type_reserved                    56889 non-null  object
#  8   lead_time                             56889 non-null  int64
#  9   market_segment_type                   56889 non-null  object
#  10  repeated_guest                        56889 non-null  int64
# ...

# %%
df.head()
# Out:
#   complete_date  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0    2017-10-02             2               0                     1
# 1    2018-11-06             2               0                     2
# 2    2018-02-28             1               0                     2
# 3    2018-05-20             2               0                     0
# 4    2019-07-13             3               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  3      Not Selected                           0
#
#   room_type_reserved  lead_time market_segment_type  repeated_guest  \
# 0        Room_Type 1        224             Offline               0
# ...

# %%
df2 = df.copy()

# %% [markdown]
# **Adding the components of date**

# %%
df['year'] = df['complete_date'].dt.year

df['month'] = df['complete_date'].dt.month

df['month_name'] = df['complete_date'].dt.month_name()

df['day'] = df['complete_date'].dt.day

df['day_name'] = df['complete_date'].dt.day_name()

# %%
df.head()
# Out:
#   complete_date  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0    2017-10-02             2               0                     1
# 1    2018-11-06             2               0                     2
# 2    2018-02-28             1               0                     2
# 3    2018-05-20             2               0                     0
# 4    2019-07-13             3               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  3      Not Selected                           0
#
#   room_type_reserved  lead_time market_segment_type  ...  \
# 0        Room_Type 1        224             Offline  ...
# ...

# %% [markdown]
# **Missing values check**

# %%
df.isna().sum()
# Out:
# complete_date                           0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# year                                    0
# month                                   0
# month_name                              0
# day                                     0
# day_name                                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 14348

# %%
# check the duplicates
# df[df.duplicated(keep = False)].sort_values(by = "complete_date")

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##   <font color= darkred> EDA </font>

# %% [markdown]
# ### Numerical enteries

# %%
df.describe()
# Out:
#                        complete_date  no_of_adults  no_of_children  \
# count                          42541  42541.000000    42541.000000
# mean   2018-10-13 20:45:11.699301888      1.917045        0.142122
# min              2017-07-01 00:00:00      0.000000        0.000000
# 25%              2018-05-12 00:00:00      2.000000        0.000000
# 50%              2018-10-15 00:00:00      2.000000        0.000000
# 75%              2019-04-14 00:00:00      2.000000        0.000000
# max              2019-08-31 00:00:00      4.000000       10.000000
# std                              NaN      0.527394        0.459879
#
#        no_of_weekend_nights  no_of_week_nights  required_car_parking_space  \
# count          42541.000000       42541.000000                42541.000000
# mean               0.895136           2.321149                    0.034320
# min                0.000000           0.000000                    0.000000
# ...

# %%
df.hist(figsize = (15, 15), grid = False);

# %% [markdown]
# ### Categorical Values

# %%
df.describe(include = 'object')
# Out:
#        type_of_meal_plan room_type_reserved market_segment_type  \
# count              42541              42541               42541
# unique                 4                  7                   5
# top          Meal Plan 1        Room_Type 1              Online
# freq               31832              29707               34149
#
#        booking_status month_name   day_name
# count           42541      42541      42541
# unique              2         12          7
# top      Not_Canceled     August  Wednesday
# freq            28061       5312       6765

# %%
cat_list = df.select_dtypes("object").columns.tolist()
cat_list
# Out:
# ['type_of_meal_plan',
#  'room_type_reserved',
#  'market_segment_type',
#  'booking_status',
#  'month_name',
#  'day_name']

# %%
for cat in cat_list:
    df[cat].value_counts().plot(kind = 'bar', title = f"Frequency count for {cat}")
#     df['type_of_meal_plan'].value_counts().plot(kind = 'bar', backend = 'plotly')
    plt.show();

# %% [markdown]
# ### Investigations

# %%
df['avg_price_per_room'].plot(kind = 'kde', xlim = (0, 600));

# %% [markdown]
# **Dropping the rows with zero prices**

# %%
df[df['avg_price_per_room'] == 0].shape
# Out:
# (641, 21)

# %%
# dropping the data with 0 prices
df = df[df['avg_price_per_room'] != 0].copy()

# %% [markdown]
# ### Univariate Analysis

# %%
df['booking_status'].value_counts(normalize= True).to_frame().style.format('{:.1%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_29b1c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29b1c_level0_col0" class="col_heading level0 col0" >proportion</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >booking_status</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29b1c_level0_row0" class="row_heading level0 row0" >Not_Canceled</th>
#       <td id="T_29b1c_row0_col0" class="data row0 col0" >65.5%</td>
#     </tr>
#     <tr>
#       <th id="T_29b1c_level0_row1" class="row_heading level0 row1" >Canceled</th>
#       <td id="T_29b1c_row1_col0" class="data row1 col0" >34.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['booking_status'].value_counts(normalize= True).round(4).multiply(100).plot(kind = 'bar', backend = 'plotly')

# %%
df['booking_status'] = df['booking_status'].replace({'Not_Canceled': 0,  'Canceled': 1})

# %%
df['booking_status'].value_counts(normalize= True).to_frame().style.format('{:.1%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a8776">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8776_level0_col0" class="col_heading level0 col0" >proportion</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >booking_status</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8776_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8776_row0_col0" class="data row0 col0" >65.5%</td>
#     </tr>
#     <tr>
#       <th id="T_a8776_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8776_row1_col0" class="data row1 col0" >34.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['booking_status'].mean()
# Out:
# 0.34534606205250595

# %%
df.groupby(['year', 'month'])['booking_status'].mean()
# Out:
# year  month
# 2017  7        0.682353
#       8        0.199670
#       9        0.119306
#       10       0.082105
#       11       0.059633
#       12       0.034646
# 2018  1        0.021362
#       2        0.222753
#       3        0.279270
#       4        0.317097
#       5        0.321409
#       6        0.328022
#       7        0.381453
#       8        0.453978
#       9        0.375907
#       10       0.381843
#       11       0.275015
#       12       0.188389
# 2019  1        0.180030
#       2        0.328387
#       3        0.317554
#       4        0.455760
#       5        0.439645
#       6        0.449818
#       7        0.546617
#       8        0.562695
# Name: booking_status, dtype: float64

# %%
df.groupby(['year', 'month'])['booking_status'].mean().plot(kind = 'line', title = "Avg. Cancellation rate across months", color = "brown");

# %%
monthly = df.groupby(['year', 'month'], as_index = False)['booking_status'].mean()
monthly.head()
# Out:
#    year  month  booking_status
# 0  2017      7        0.682353
# 1  2017      8        0.199670
# 2  2017      9        0.119306
# 3  2017     10        0.082105
# 4  2017     11        0.059633

# %%
sns.lineplot(data = monthly, x = 'month', y = 'booking_status', hue = 'year',  palette='Set1');
plt.title("Avg Cancellation Rate");

# %% [markdown]
# ### Bivariate Analysis

# %%
corr = (df
        .drop(columns = ['year', 'month', 'day'])
        .corr(numeric_only = True, method = "kendall")
        .round(3)
       )

plt.figure(figsize= (15,8))
sns.heatmap(corr, annot= True);

# %%
# corr["booking_status"].sort_values()[:-1].plot(kind = "bar");

# %%
np.abs(corr["booking_status"]).sort_values()[:-1].plot(kind = "bar");

# %% [markdown]
# **Based on the correlation values**

# %%
df.groupby('booking_status')['lead_time'].mean().round()
# Out:
# booking_status
# 0     55.0
# 1    122.0
# Name: lead_time, dtype: float64

# %%
df.groupby('booking_status')['lead_time'].median().round()
# Out:
# booking_status
# 0     36.0
# 1    110.0
# Name: lead_time, dtype: float64

# %%
df.groupby('booking_status')['avg_price_per_room'].median().round()
# Out:
# booking_status
# 0    100.0
# 1    117.0
# Name: avg_price_per_room, dtype: float64

# %%
pd.crosstab(df['booking_status'], df['repeated_guest'], normalize= True).round(3)
# Out:
# repeated_guest      0      1
# booking_status
# 0               0.628  0.026
# 1               0.345  0.000

# %% [markdown]
# ##  <font color= darkred> Data Prep for Modeling </font>

# %% [markdown]
# ### Train-Test Split

# %%
# data prep
from sklearn.model_selection import train_test_split

# %%
# splitting the data 
X = df.drop(columns = 'booking_status')
y = df['booking_status']

# %%
# # doing train test split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %%
print("x_train: ", x_train.shape)
print("y_train: ", y_train.shape)


print("\n")

print("x_test: ", x_test.shape)
print("y_test: ", y_test.shape)

display(x_train.head())
display(y_train.head())
# Out:
# x_train:  (33520, 20)
# y_train:  (33520,)
#
#
# x_test:  (8380, 20)
# y_test:  (8380,)
#       complete_date  no_of_adults  no_of_children  no_of_weekend_nights  \
# 45925    2019-08-06             2               0                     2
# 51305    2018-07-10             3               0                     2
# 15898    2018-04-11             2               0                     2
# 35652    2019-05-28             2               0                     2
# 9838     2018-08-08             2               2                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 45925                  3       Meal Plan 1                           0
# 51305                  2       Meal Plan 1                           0
# 15898                  5       Meal Plan 1                           0
# 35652                  4       Meal Plan 1                           0
# 9838                   0       Meal Plan 1                           0
#
# ...

# %% [markdown]
# ### Pre-processing

# %%
numerical_cols = x_train.select_dtypes(["int", "float"]).drop(columns = ["year", "month", "day"]).columns
numerical_cols
# x_train[numerical_cols]
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'required_car_parking_space', 'lead_time',
#        'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests'],
#       dtype='object')

# %%
categorical_cols = x_train.select_dtypes(["object"]).drop(columns = ["month_name", "day_name"]).columns.tolist()

categorical_cols
# x_train[categorical_cols]
# Out:
# ['type_of_meal_plan', 'room_type_reserved', 'market_segment_type']

# %% [markdown]
# **Transformation**

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
numerical_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown = "ignore")

# %% [markdown]
# **We will use ColumnTransformer for handling multiple column types**

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols), # Apply scaler to numerical columns
        ('cat', categorical_transformer, categorical_cols) # Apply one-hot encoding to categorical columns
    ]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'required_car_parking_space', 'lead_time',
#        'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests'],
#       dtype='object')),
#                                 ('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  ['type_of_meal_plan', 'room_type_reserved',
#                                   'market_segment_type'])])

# %% [markdown]
# ## <font color= darkred> Model building </font> 💥⚡

# %%
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report

# %%
pipeline = Pipeline(steps = 
                    [("preprocessor", preprocessor),
                     ("classifier", LogisticRegression())
    
])

# %%
pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'required_car_parking_space', 'lead_time',
#        'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['type_of_meal_plan',
#                                                    'room_type_reserved',
#                                                    'market_segment_type'])])),
#                 ('classifier', LogisticRegression())])

# %%
# fit the model 
pipeline.fit(x_train, y_train)

# scoring on train 
print(f"Train data accuracy: {pipeline.score(x_train, y_train):.2f}")

# scoring on test 
print(f"Test data accuracy: {pipeline.score(x_test, y_test):.2f}") # conformation on the transformation
# Out:
# Train data accuracy: 0.79
# Test data accuracy: 0.79

# %%
pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'required_car_parking_space', 'lead_time',
#        'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['type_of_meal_plan',
#                                                    'room_type_reserved',
#                                                    'market_segment_type'])])),
#                 ('classifier', LogisticRegression())])

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# extract the classifier
pipeline.named_steps["classifier"]
# Out:
# LogisticRegression()

# %%
# extract the classes
lr_class = pipeline.named_steps["classifier"].classes_
lr_class
# Out:
# array([0, 1], dtype=int64)

# %%
test_predictions = pipeline.predict(x_test)

# generate the confusion matrix
cm = confusion_matrix(y_test, test_predictions, labels = lr_class)
cm = confusion_matrix(y_test, test_predictions)

# display 
disp = ConfusionMatrixDisplay(confusion_matrix = cm,display_labels = lr_class)

# show the plot
disp.plot()
plt.show()

# %% [markdown]
# **Confusion Matrix Evaluation**

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, test_predictions, target_names= ["Non Cancelled", "Cancelled"]))
# Out:
#                precision    recall  f1-score   support
#
# Non Cancelled       0.81      0.88      0.84      5459
#     Cancelled       0.73      0.61      0.67      2921
#
#      accuracy                           0.79      8380
#     macro avg       0.77      0.75      0.76      8380
#  weighted avg       0.78      0.79      0.78      8380

# %% [markdown]
# #### Explanation
#
# **Non-Cancellations**
# * Precision: 82% of the items predicted as non-cancellations are actually so (4812/5941)
# * Recall: 88% of non-cancelled rooms were correctly classified (4812/5459)
#
# **Cancellations**
#
# * 73% of cancellations predicted are actual cancellations (1792/2439)
# * 61% of cancellations were correctly classified (1792/2921);
#     * 2921 --> actual cancellations
#     * 2439 --> predicted cancellations

# %% [markdown]
# ### Logistic Regression Model Coefficients

# %%
import pprint #https://docs.python.org/3/library/pprint.html

# %%
feature_names = pipeline.named_steps["preprocessor"].get_feature_names_out()
# print(feature_names,"\n")

# clean the feature names
clean_feature_names = [name.split('__')[-1] for name in feature_names]
# pprint.pp(clean_feature_names)

# %%
coefficients = pipeline.named_steps["classifier"].coef_[0] # the [0] is to extract the values in single array

# converting into df 
lr_results = pd.DataFrame({"columns": clean_feature_names, "values" : coefficients}).sort_values(by = "values")

# bar plot
lr_results.plot(kind = 'barh', x = 'columns', y = 'values', legend = False);

# Adding labels and title to the plot
plt.title('Logistic Regression Coefficients')

# Display the plot
plt.show()

# %%
lr_results
# Out:
#                                  columns    values
# 23     market_segment_type_Complementary -1.779824
# 25           market_segment_type_Offline -1.235883
# 10                no_of_special_requests -1.098723
# 12         type_of_meal_plan_Meal Plan 2 -0.579842
# 21        room_type_reserved_Room_Type 7 -0.538027
# 11         type_of_meal_plan_Meal Plan 1 -0.442635
# 6                         repeated_guest -0.411228
# 20        room_type_reserved_Room_Type 6 -0.316755
# 4             required_car_parking_space -0.260333
# 14        type_of_meal_plan_Not Selected -0.136192
# 16        room_type_reserved_Room_Type 2 -0.123218
# 17        room_type_reserved_Room_Type 3 -0.073259
# 8   no_of_previous_bookings_not_canceled -0.073085
# 0                           no_of_adults -0.006375
# 2                   no_of_weekend_nights  0.038898
# 1                         no_of_children  0.057562
# 19        room_type_reserved_Room_Type 5  0.069053
# ...

# %% [markdown]
# **Interpretation**
# * In logistic regression, the coefficients represent the change in the log-odds of the target variable (cancellation, in this case)
# * The negative value means it decreases the log odds of cancellation. So being a repeated guest has a strong effect on reducing the likelihood of cancellation
# * The positive values means it increases the log odds of cancellation.The lead time has a strong effect on increasing the likelihood of cancellation

# %% [markdown]
# ### ROC - AUC Curve

# %%
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# **Dummy Classifier**

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'required_car_parking_space', 'lead_time',
#        'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests'],
#       dtype='object')),
#                                 ('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  ['type_of_meal_plan', 'room_type_reserved',
#                                   'market_segment_type'])])

# %%
# call dummy 
dummy_clf = DummyClassifier()  

# fit dummy 
dummy_clf.fit(preprocessor.fit_transform(x_train) , y_train)

# predict probability
y_pred_prob_dummy = dummy_clf.predict_proba(preprocessor.transform(x_test) )[:, 1]

# compute values
fpr_dummy, tpr_dummy, thresholds_dummy = roc_curve(y_test, y_pred_prob_dummy)

# auc
roc_auc_dummy = auc(fpr_dummy, tpr_dummy)

# %% [markdown]
# **Logistic Regression**

# %%
# get the probability score
y_pred_prob = pipeline.predict_proba(x_test)[:, 1] # get the probability of class 1

# compute values
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# calculate auc
roc_auc = auc(fpr, tpr)

# %%
# Plot ROC curve
plt.figure(figsize=(8, 6))

plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot(fpr_dummy, tpr_dummy, color='blue', lw=2, linestyle='--', label='Dummy Classifier (area = %0.2f)' % roc_auc_dummy)

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line (random classifier)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# * A higher AUC value means better performance. A model with AUC close to 1 is very good, while a model with AUC close to 0.5 is performing no better than random guessing.
#
# * ROC: The closer the curve is to the top-left corner, the better the model.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Reference material 📚
#
#
# * [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/): good book for hands on practice and codes.
# * [ISLR](https://www.statlearning.com/)- good coverage of the theory
#
# </div>
